# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

# %%
file_path = 'Data_Sheet_1_Association between socioeconomic status and arteriosclerotic cardiovascular disease risk and cause-specific and all-cause mortality.CSV' 
data = pd.read_csv(file_path)

# %%
features = data[['PIR', 'edu', 'poverty', "eth", "sex", "PHQ9"]]
target = data['ASCVD']

categorical_columns = features.select_dtypes(include=['object']).columns
features = pd.get_dummies(features, columns=categorical_columns, drop_first=True)
features = features.fillna(features.median())
target = target.fillna(target.median())

target = target.astype(int)

X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=33)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

y_train = np.array(y_train).astype(int).reshape(-1)
y_test = np.array(y_test).astype(int).reshape(-1)

# %%
from tensorflow.keras.layers import LeakyReLU

model = tf.keras.Sequential([
    layers.InputLayer(input_shape=(X_train.shape[1],)),

    # First hidden layer
    layers.Dense(128, kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    LeakyReLU(alpha=0.1),
    layers.BatchNormalization(),
    layers.Dropout(0.3), 

    # Second hidden layer
    layers.Dense(64, kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    LeakyReLU(alpha=0.1),
    layers.BatchNormalization(),
    layers.Dropout(0.2),

    # Third hidden layer
    layers.Dense(32, kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    LeakyReLU(alpha=0.1),
    layers.BatchNormalization(),
    layers.Dropout(0.2),

    # Fourth hidden layer
    layers.Dense(32, kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    LeakyReLU(alpha=0.1),
    layers.BatchNormalization(),
    layers.Dropout(0.2),

    layers.Dense(1, activation='sigmoid')
])

# Compile the model with RMSprop optimizer
# optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

# lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
#     initial_learning_rate=0.0001,
#     decay_steps=1000,
#     decay_rate=0.96,
#     staircase=True
# )
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train),
    y=y_train
)
class_weight_dict = {0: class_weights[0], 1: class_weights[1]}
print(f"Class Weights: {class_weight_dict}")

# Train the model
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    callbacks=[early_stopping],
    class_weight=class_weight_dict
)

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {accuracy:.2f}')

# Make predictions
predictions = model.predict(X_test)
# Out:
# C:\Users\Jasmine Garcia\anaconda3\Lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# C:\Users\Jasmine Garcia\anaconda3\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Class Weights: {0: 0.5545504892006645, 1: 5.082910321489002}
# Epoch 1/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.4896 - loss: 1.1235 - val_accuracy: 0.4267 - val_loss: 1.0068
# Epoch 2/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5179 - loss: 0.9854 - val_accuracy: 0.5059 - val_loss: 0.9429
# Epoch 3/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5301 - loss: 0.9629 - val_accuracy: 0.5124 - val_loss: 0.9245
# Epoch 4/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5262 - loss: 0.9369 - val_accuracy: 0.5259 - val_loss: 0.8888
# Epoch 5/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5404 - loss: 0.9062 - val_accuracy: 0.5130 - val_loss: 0.8869
# Epoch 6/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5415 - loss: 0.9058 - val_accuracy: 0.5178 - val_loss: 0.8690
# Epoch 7/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5458 - loss: 0.8878 - val_accuracy: 0.5457 - val_loss: 0.8556
# Epoch 8/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5567 - loss: 0.8751 - val_accuracy: 0.5488 - val_loss: 0.8443
# Epoch 9/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5424 - loss: 0.8877 - val_accuracy: 0.5315 - val_loss: 0.8452
# Epoch 10/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5472 - loss: 0.8735 - val_accuracy: 0.5311 - val_loss: 0.8445
# Epoch 11/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5402 - loss: 0.8989 - val_accuracy: 0.5419 - val_loss: 0.8371
# Epoch 12/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5479 - loss: 0.8683 - val_accuracy: 0.5527 - val_loss: 0.8251
# Epoch 13/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5443 - loss: 0.8612 - val_accuracy: 0.5442 - val_loss: 0.8276
# Epoch 14/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5472 - loss: 0.8589 - val_accuracy: 0.5348 - val_loss: 0.8275
# Epoch 15/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5516 - loss: 0.8578 - val_accuracy: 0.5513 - val_loss: 0.8149
# Epoch 16/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5437 - loss: 0.8497 - val_accuracy: 0.5592 - val_loss: 0.8179
# Epoch 17/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5475 - loss: 0.8343 - val_accuracy: 0.5529 - val_loss: 0.8142
# Epoch 18/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5479 - loss: 0.8473 - val_accuracy: 0.5650 - val_loss: 0.8068
# Epoch 19/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5575 - loss: 0.8379 - val_accuracy: 0.5679 - val_loss: 0.8051
# Epoch 20/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5524 - loss: 0.8167 - val_accuracy: 0.5663 - val_loss: 0.7967
# Epoch 21/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5486 - loss: 0.8178 - val_accuracy: 0.5538 - val_loss: 0.8016
# Epoch 22/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5458 - loss: 0.8210 - val_accuracy: 0.5617 - val_loss: 0.7979
# Epoch 23/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5512 - loss: 0.8132 - val_accuracy: 0.5642 - val_loss: 0.7959
# Epoch 24/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5623 - loss: 0.7999 - val_accuracy: 0.5613 - val_loss: 0.7945
# Epoch 25/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5601 - loss: 0.8076 - val_accuracy: 0.5663 - val_loss: 0.7912
# Epoch 26/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5570 - loss: 0.7990 - val_accuracy: 0.5563 - val_loss: 0.7879
# Epoch 27/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5533 - loss: 0.8021 - val_accuracy: 0.5500 - val_loss: 0.7850
# Epoch 28/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5572 - loss: 0.7909 - val_accuracy: 0.5480 - val_loss: 0.7870
# Epoch 29/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5590 - loss: 0.8032 - val_accuracy: 0.5602 - val_loss: 0.7810
# Epoch 30/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5638 - loss: 0.7926 - val_accuracy: 0.5488 - val_loss: 0.7809
# Epoch 31/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5580 - loss: 0.7712 - val_accuracy: 0.5550 - val_loss: 0.7800
# Epoch 32/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5656 - loss: 0.7771 - val_accuracy: 0.5546 - val_loss: 0.7723
# Epoch 33/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5588 - loss: 0.7748 - val_accuracy: 0.5523 - val_loss: 0.7688
# Epoch 34/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5620 - loss: 0.7847 - val_accuracy: 0.5465 - val_loss: 0.7660
# Epoch 35/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5667 - loss: 0.7730 - val_accuracy: 0.5515 - val_loss: 0.7688
# Epoch 36/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5674 - loss: 0.7670 - val_accuracy: 0.5507 - val_loss: 0.7632
# Epoch 37/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5759 - loss: 0.7644 - val_accuracy: 0.5569 - val_loss: 0.7533
# Epoch 38/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5726 - loss: 0.7544 - val_accuracy: 0.5519 - val_loss: 0.7579
# Epoch 39/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.5710 - loss: 0.7627 - val_accuracy: 0.5602 - val_loss: 0.7528
# Epoch 40/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5796 - loss: 0.7496 - val_accuracy: 0.5600 - val_loss: 0.7562
# Epoch 41/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5639 - loss: 0.7573 - val_accuracy: 0.5754 - val_loss: 0.7504
# Epoch 42/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5666 - loss: 0.7592 - val_accuracy: 0.5904 - val_loss: 0.7427
# Epoch 43/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5743 - loss: 0.7567 - val_accuracy: 0.5881 - val_loss: 0.7397
# Epoch 44/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5756 - loss: 0.7455 - val_accuracy: 0.5523 - val_loss: 0.7421
# Epoch 45/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5788 - loss: 0.7494 - val_accuracy: 0.5719 - val_loss: 0.7392
# Epoch 46/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5780 - loss: 0.7491 - val_accuracy: 0.5723 - val_loss: 0.7299
# Epoch 47/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5811 - loss: 0.7355 - val_accuracy: 0.5814 - val_loss: 0.7298
# Epoch 48/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5826 - loss: 0.7402 - val_accuracy: 0.5636 - val_loss: 0.7308
# Epoch 49/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5755 - loss: 0.7330 - val_accuracy: 0.5656 - val_loss: 0.7251
# Epoch 50/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5809 - loss: 0.7354 - val_accuracy: 0.5719 - val_loss: 0.7193
# Epoch 51/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5737 - loss: 0.7502 - val_accuracy: 0.5765 - val_loss: 0.7177
# Epoch 52/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5783 - loss: 0.7274 - val_accuracy: 0.5640 - val_loss: 0.7219
# Epoch 53/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5734 - loss: 0.7330 - val_accuracy: 0.5717 - val_loss: 0.7200
# Epoch 54/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5837 - loss: 0.7259 - val_accuracy: 0.5877 - val_loss: 0.7209
# Epoch 55/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5820 - loss: 0.7318 - val_accuracy: 0.5864 - val_loss: 0.7172
# Epoch 56/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5909 - loss: 0.7206 - val_accuracy: 0.5937 - val_loss: 0.7116
# Epoch 57/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5832 - loss: 0.7199 - val_accuracy: 0.5860 - val_loss: 0.7114
# Epoch 58/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5872 - loss: 0.7088 - val_accuracy: 0.5921 - val_loss: 0.7100
# Epoch 59/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5928 - loss: 0.7015 - val_accuracy: 0.5993 - val_loss: 0.7041
# Epoch 60/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5972 - loss: 0.7055 - val_accuracy: 0.5860 - val_loss: 0.7102
# Epoch 61/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5807 - loss: 0.7059 - val_accuracy: 0.5896 - val_loss: 0.7086
# Epoch 62/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5929 - loss: 0.7140 - val_accuracy: 0.5704 - val_loss: 0.7073
# Epoch 63/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5877 - loss: 0.7001 - val_accuracy: 0.5721 - val_loss: 0.7069
# Epoch 64/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5846 - loss: 0.6997 - val_accuracy: 0.5704 - val_loss: 0.7074
# Epoch 65/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5868 - loss: 0.7116 - val_accuracy: 0.5690 - val_loss: 0.7004
# Epoch 66/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5806 - loss: 0.7075 - val_accuracy: 0.5625 - val_loss: 0.7051
# Epoch 67/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5800 - loss: 0.7047 - val_accuracy: 0.5692 - val_loss: 0.7005
# Epoch 68/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5772 - loss: 0.6968 - val_accuracy: 0.5879 - val_loss: 0.6918
# Epoch 69/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5831 - loss: 0.7021 - val_accuracy: 0.5858 - val_loss: 0.6905
# Epoch 70/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5775 - loss: 0.6939 - val_accuracy: 0.5879 - val_loss: 0.6908
# Epoch 71/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5883 - loss: 0.7016 - val_accuracy: 0.5785 - val_loss: 0.6929
# Epoch 72/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5972 - loss: 0.6790 - val_accuracy: 0.5916 - val_loss: 0.6875
# Epoch 73/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5986 - loss: 0.6871 - val_accuracy: 0.5991 - val_loss: 0.6871
# Epoch 74/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5941 - loss: 0.6935 - val_accuracy: 0.6052 - val_loss: 0.6787
# Epoch 75/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5986 - loss: 0.6896 - val_accuracy: 0.6072 - val_loss: 0.6858
# Epoch 76/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5911 - loss: 0.7003 - val_accuracy: 0.5760 - val_loss: 0.6872
# Epoch 77/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5927 - loss: 0.6864 - val_accuracy: 0.5800 - val_loss: 0.6869
# Epoch 78/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5904 - loss: 0.6936 - val_accuracy: 0.5973 - val_loss: 0.6848
# Epoch 79/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5980 - loss: 0.6830 - val_accuracy: 0.6012 - val_loss: 0.6819
# Epoch 80/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5954 - loss: 0.6800 - val_accuracy: 0.5873 - val_loss: 0.6840
# Epoch 81/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5919 - loss: 0.6907 - val_accuracy: 0.5935 - val_loss: 0.6820
# Epoch 82/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5929 - loss: 0.6799 - val_accuracy: 0.6274 - val_loss: 0.6701
# Epoch 83/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6000 - loss: 0.6848 - val_accuracy: 0.5896 - val_loss: 0.6817
# Epoch 84/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6001 - loss: 0.6830 - val_accuracy: 0.5889 - val_loss: 0.6793
# Epoch 85/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5958 - loss: 0.6763 - val_accuracy: 0.5937 - val_loss: 0.6744
# Epoch 86/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5967 - loss: 0.6755 - val_accuracy: 0.5910 - val_loss: 0.6738
# Epoch 87/100
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5861 - loss: 0.6773 - val_accuracy: 0.6052 - val_loss: 0.6723
# Epoch 88/100
# 402/601 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6024 - loss: 0.6698

# %%
import seaborn as sns
import numpy as np
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

binary_predictions = (predictions > 0.5).astype(int)

cm = confusion_matrix(y_test, binary_predictions)

cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

labels = ["Negative ASCVD", "Positive ASCVD"]

plt.figure(figsize=(8, 6))
sns.heatmap(cm_normalized, annot=True, fmt=".2%", cmap="Blues", xticklabels=labels, yticklabels=labels)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Normalized Confusion Matrix for MLP")
plt.show()

# %%
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
train_loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 6))
plt.plot(train_acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy Over Epochs')
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(8, 6))
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss Over Epochs')
plt.legend()
plt.grid()
plt.show()
